# %%
import cx_Oracle

# %%
connection=cx_Oracle.connect("litu","litu","//localhost/orcl")
cursor=connection.cursor()
rs=cursor.execute("select * from CHICAGO_CRIME_DATA")

# %%
for row in rs:
    print(row)

# %%
# %load_ext sql

# %%
# %sql oracle+cx_oracle://litu:litu@localhost/?service_name=orcl

# %%
# %sql select * from CHICAGO_CRIME_DATA
# Out:
#  * oracle+cx_oracle://litu:***@localhost/?service_name=orcl
# 0 rows affected.
# [(3512276, 'HK587712', '8/28/2004', '047XX S KEDZIE AVE', 890, 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, '6', 1155838, 1873050, 2004, Decimal('41.8074405'), Decimal('-87.70395585'), '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '6/26/2004', '009XX N CENTRAL PARK AVE', 820, 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, '6', 1152206, 1906127, 2004, Decimal('41.89827996'), Decimal('-87.71640551'), '(41.898279962, -87.716405505)'),
#  (8002131, 'HT233595', '4/4/2011', '043XX S WABASH AVE', 820, 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 'FALSE', 'FALSE', 221, 2, 3, 38, '6', 1177436, 1876313, 2011, Decimal('41.81593313'), Decimal('-87.62464213'), '(41.815933131, -87.624642127)'),
# ...

# %%
# %sql select count(distinct ID) from CHICAGO_CRIME_DATA
# Out:
#  * oracle+cx_oracle://litu:***@localhost/?service_name=orcl
# 0 rows affected.
# [(532,)]

# %%
# %%sql
# select COMMUNITY_AREA_NAME,HARDSHIP_INDEX
# from CENSUS_DATA
# where HARDSHIP_INDEX=(select max(HARDSHIP_INDEX) from CENSUS_DATA)
# Out:
#  * oracle+cx_oracle://litu:***@localhost/?service_name=orcl
# 0 rows affected.
# [('Riverdale', 98)]

# %%
# %%sql
# select *from MUTUAL_FUND where APPX_EPU>0
# and APPX_EPU<1
# and RANGE_OF_VALUATION like '%Heavily Undervalued%'
# order by APPX_EPU desc
# Out:
#  * oracle+cx_oracle://litu:***@localhost/?service_name=orcl
# 0 rows affected.
# [('PHPMF1', Decimal('6.6'), Decimal('11.83'), Decimal('11.28'), Decimal('0.55'), Decimal('79.24'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('FBFIF', Decimal('5.9'), Decimal('11.68'), Decimal('11.14'), Decimal('0.54'), Decimal('97.97'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('EXIM1STMF', Decimal('6.9'), Decimal('11.98'), Decimal('11.45'), Decimal('0.53'), Decimal('73.62'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('IFIC1STMF', Decimal('6.5'), Decimal('11.54'), Decimal('11.35'), Decimal('0.19'), Decimal('77.54'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('POPULAR1MF', Decimal('6.1'), Decimal('11.8'), Decimal('11.63'), Decimal('0.17'), Decimal('93.44'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('TRUSTB1MF', Decimal('6.8'), Decimal('11.89'), Decimal('11.72'), Decimal('0.17'), Decimal('74.85'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
# ...

# %%
# %%sql
# select *from MUTUAL_FUND
# where RANGE_OF_VALUATION like '%Overvalued%'
# order by APPX_EPU
# Out:
#  * oracle+cx_oracle://litu:***@localhost/?service_name=orcl
# 0 rows affected.
# [('1STPRIMFMF', Decimal('20.3'), Decimal('13.53'), Decimal('18.24'), Decimal('-4.71'), Decimal('-33.35'), 'ICB', 'Overvalued', 'Moderately Overvalued'),
#  ('ICBAMCL2ND', Decimal('10.3'), Decimal('10.04'), Decimal('13.73'), Decimal('-3.69'), Decimal('-2.52'), 'ICB', 'Overvalued', 'Slightly Overvalued'),
#  ('PF1STMF', Decimal('12.8'), Decimal('9.32'), Decimal('12.09'), Decimal('-2.77'), Decimal('-27.19'), 'ICB', 'Overvalued', 'Slightly Overvalued'),
#  ('SEMLIBBLSF', Decimal('13.2'), Decimal('11.28'), Decimal('11.87'), Decimal('-0.59'), Decimal('-14.55'), 'STRATEGIC', 'Overvalued', 'Slightly Overvalued'),
#  ('CAPMIBBLMF', Decimal('22.3'), Decimal('11.87'), Decimal('11.53'), Decimal('0.34'), Decimal('-46.77'), 'CAPM', 'Overvalued', 'Moderately Overvalued'),
# ...

# %%
# %%sql
# select *from (select *from MUTUAL_FUND where APPX_EPU>.5
# and APPX_EPU<1
# and RANGE_OF_VALUATION like '%Heavily Undervalued%'
# order by percentage_U_O desc)
# where rownum<=5
# Out:
#  * oracle+cx_oracle://litu:***@localhost/?service_name=orcl
# 0 rows affected.
# [('FBFIF', Decimal('5.9'), Decimal('11.68'), Decimal('11.14'), Decimal('0.54'), Decimal('97.97'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('PHPMF1', Decimal('6.6'), Decimal('11.83'), Decimal('11.28'), Decimal('0.55'), Decimal('79.24'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('EXIM1STMF', Decimal('6.9'), Decimal('11.98'), Decimal('11.45'), Decimal('0.53'), Decimal('73.62'), 'RACE', 'Undervalued', 'Heavily Undervalued')]

# %%
import pandas as pd

# %%
df=pd.read_sql('select *from MUTUAL_FUND',connection)
df
# Out:
#      FUND_NAME   LTP  NAV_MP  NAV_CP  APPX_EPU  PERCENTAGE_U_O ASSET_MANAGER  \
# 0    1JANATAMF   6.7   11.83   11.79      0.04           76.57          RACE
# 1   1STPRIMFMF  20.3   13.53   18.24     -4.71          -33.35           ICB
# 2     ABB1STMF   6.7   11.94   12.00     -0.06           78.21          RACE
# 3   AIBL1STIMF   9.3   11.97   11.31      0.66           28.71     LRGGLOBAL
# 4      ATCSLGF  11.0   12.37   12.00      0.37           12.45    AT-CAPITAL
# 5   CAPMBDBLMF  10.5   11.67   11.74     -0.07           11.14          CAPM
# 6   CAPMIBBLMF  22.3   11.87   11.53      0.34          -46.77          CAPM
# 7     DBH1STMF   7.6   11.88   11.07      0.81           56.32     LRGGLOBAL
# 8     EBL1STMF   7.5   11.74   11.61      0.13           56.53          RACE
# 9     EBLNRBMF   6.8   12.20   11.17      1.03           79.41          RACE
# 10   EXIM1STMF   6.9   11.98   11.45      0.53           73.62          RACE
# ...

# %%
df.describe()
# Out:
#              LTP     NAV_MP     NAV_CP   APPX_EPU  PERCENTAGE_U_O
# count  36.000000  36.000000  36.000000  36.000000       36.000000
# mean    9.613889  11.845556  11.874722  -0.029167       34.940278
# std     3.915767   1.999372   1.272856   2.227910       36.159380
# min     5.900000   8.900000  10.540000  -4.710000      -46.770000
# 25%     6.800000  11.415000  11.275000  -0.640000       13.035000
# 50%     8.250000  11.820000  11.625000   0.200000       29.795000
# 75%    10.575000  12.220000  12.000000   0.697500       63.600000
# max    22.300000  20.420000  18.240000   8.920000       97.970000

# %%
df.describe(include='all')
# Out:
#          FUND_NAME        LTP     NAV_MP     NAV_CP   APPX_EPU  \
# count           36  36.000000  36.000000  36.000000  36.000000
# unique          36        NaN        NaN        NaN        NaN
# top     ICBSONALI1        NaN        NaN        NaN        NaN
# freq             1        NaN        NaN        NaN        NaN
# mean           NaN   9.613889  11.845556  11.874722  -0.029167
# std            NaN   3.915767   1.999372   1.272856   2.227910
# min            NaN   5.900000   8.900000  10.540000  -4.710000
# 25%            NaN   6.800000  11.415000  11.275000  -0.640000
# 50%            NaN   8.250000  11.820000  11.625000   0.200000
# 75%            NaN  10.575000  12.220000  12.000000   0.697500
# max            NaN  22.300000  20.420000  18.240000   8.920000
#
#         PERCENTAGE_U_O ASSET_MANAGER  UNDEROROVER    RANGE_OF_VALUATION
# count        36.000000            36           36                    36
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      FUND_NAME   LTP  NAV_MP  NAV_CP  APPX_EPU  PERCENTAGE_U_O ASSET_MANAGER  \
# 0    1JANATAMF   6.7   11.83   11.79      0.04           76.57          RACE
# 1   1STPRIMFMF  20.3   13.53   18.24     -4.71          -33.35           ICB
# 2     ABB1STMF   6.7   11.94   12.00     -0.06           78.21          RACE
# 3   AIBL1STIMF   9.3   11.97   11.31      0.66           28.71     LRGGLOBAL
# 4      ATCSLGF  11.0   12.37   12.00      0.37           12.45    AT-CAPITAL
# 5   CAPMBDBLMF  10.5   11.67   11.74     -0.07           11.14          CAPM
# 6   CAPMIBBLMF  22.3   11.87   11.53      0.34          -46.77          CAPM
# 7     DBH1STMF   7.6   11.88   11.07      0.81           56.32     LRGGLOBAL
# 8     EBL1STMF   7.5   11.74   11.61      0.13           56.53          RACE
# 9     EBLNRBMF   6.8   12.20   11.17      1.03           79.41          RACE
# 10   EXIM1STMF   6.9   11.98   11.45      0.53           73.62          RACE
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plot=sns.swarmplot(x='FUND_NAME',y='LTP',data=df)
plt.setp(plot.get_xticklabels(),rotation=100)
plt.title('LTP with name')
plt.show()

# %% [markdown]
# # which MF has the higehst LTP

# %%
df['LTP'].describe()
# Out:
# count    36.000000
# mean      9.613889
# std       3.915767
# min       5.900000
# 25%       6.800000
# 50%       8.250000
# 75%      10.575000
# max      22.300000
# Name: LTP, dtype: float64

# %%
df['LTP'].idxmax()
# Out:
# 6

# %%
df.at[6,'FUND_NAME']
# Out:
# 'CAPMIBBLMF'

# %% [markdown]
# # Further data Exploration

# %%
plot=sns.jointplot(x='APPX_EPU',y='NAV_MP',data=df)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plot=sns.set_style("whitegrid")
ax=sns.boxplot(x=df["LTP"])
plt.show()
