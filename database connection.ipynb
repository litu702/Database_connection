# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
import cx_Oracle

# %%
connection=cx_Oracle.connect("litu","litu","//localhost/orcl")

# %%
cursor=connection.cursor()
rs=cursor.execute("select * from mutual_fund")

# %%
for row in rs:
    print(row)
# Out:
# ('1JANATAMF', 6.6, 11.85, 11.69, 0.16, 79.55, 'RACE', 'Undervalued', 'Heavily Undervalued')
# ('1STPRIMFMF', 19.7, 12.82, 17.89, -5.07, -34.92, 'ICB', 'Overvalued', 'Moderately Overvalued')
# ('ABB1STMF', 6.7, 11.95, 11.98, -0.03, 78.36, 'RACE', 'Undervalued', 'Heavily Undervalued')
# ('AIBL1STIMF', 9.9, 11.89, 11.31, 0.58, 20.1, 'LRGGLOBAL', 'Undervalued', 'Slightly Undervalued')
# ('ATCSLGF', 10.6, 12.4, 11.95, 0.45, 16.98, 'AT-CAPITAL', 'Undervalued', 'Slightly Undervalued')
# ('CAPMBDBLMF', 10.3, 11.4, 11.74, -0.34, 10.68, 'CAPM', 'Undervalued', 'Slightly Undervalued')
# ('CAPMIBBLMF', 22.6, 11.61, 11.54, 0.07, -48.63, 'CAPM', 'Overvalued', 'Moderately Overvalued')
# ('DBH1STMF', 7.7, 11.9, 11.07, 0.83, 54.55, 'LRGGLOBAL', 'Undervalued', 'Moderately Undervalued')
# ('EBL1STMF', 7.6, 11.81, 11.51, 0.3, 55.39, 'RACE', 'Undervalued', 'Moderately Undervalued')
# ('EBLNRBMF', 6.8, 11.96, 11.15, 0.81, 75.88, 'RACE', 'Undervalued', 'Heavily Undervalued')
# ('EXIM1STMF', 6.8, 11.79, 11.46, 0.33, 73.38, 'RACE', 'Undervalued', 'Heavily Undervalued')
# ('FBFIF', 5.9, 11.67, 11.11, 0.56, 97.8, 'RACE', 'Undervalued', 'Heavily Undervalued')
# ('GRAMEENS2', 17.4, 20.14, 11.45, 8.69, 15.75, 'AIMS', 'Undervalued', 'Slightly Undervalued')
# ('GREENDELMF', 8.0, 11.67, 11.09, 0.58, 45.88, 'LRGGLOBAL', 'Undervalued', 'Moderately Undervalued')
# ('ICB3RDNRB', 6.8, 8.59, 11.79, -3.2, 26.32, 'ICB', 'Undervalued', 'Slightly Undervalued')
# ('ICBAGRANI1', 9.0, 10.46, 11.19, -0.73, 16.22, 'ICB', 'Undervalued', 'Slightly Undervalued')
# ('ICBAMCL2ND', 10.2, 9.75, 13.67, -3.92, -4.41, 'ICB', 'Overvalued', 'Slightly Overvalued')
# ('ICBEPMF1S1', 7.4, 8.64, 11.98, -3.34, 16.76, 'ICB', 'Undervalued', 'Slightly Undervalued')
# ('ICBSONALI1', 8.9, 9.75, 11.71, -1.96, 9.55, 'ICB', 'Undervalued', 'Slightly Undervalued')
# ('IFIC1STMF', 6.4, 11.59, 11.35, 0.24, 81.09, 'RACE', 'Undervalued', 'Heavily Undervalued')
# ('IFILISLMF1', 6.7, 8.75, 11.0, -2.25, 30.6, 'RACE', 'Undervalued', 'Moderately Undervalued')
# ('LRGLOBMF1', 7.6, 12.32, 11.21, 1.11, 62.11, 'LRGGLOBAL', 'Undervalued', 'Heavily Undervalued')
# ('MBL1STMF', 9.1, 12.27, 11.26, 1.01, 34.84, 'LRGGLOBAL', 'Undervalued', 'Moderately Undervalued')
# ('NCCBLMF1', 8.4, 11.78, 10.54, 1.24, 40.24, 'LRGGLOBAL', 'Undervalued', 'Moderately Undervalued')
# ('NLI1STMF', 15.3, 15.23, 13.84, 1.39, -0.46, 'VIPB', 'Overvalued', 'Slightly Overvalued')
# ('PF1STMF', 11.5, 9.03, 12.03, -3.0, -21.48, 'ICB', 'Overvalued', 'Slightly Overvalued')
# ('PHPMF1', 6.5, 11.76, 11.25, 0.51, 80.92, 'RACE', 'Undervalued', 'Heavily Undervalued')
# ('POPULAR1MF', 6.0, 11.81, 11.62, 0.19, 96.83, 'RACE', 'Undervalued', 'Heavily Undervalued')
# ('PRIME1ICBA', 7.6, 9.37, 12.06, -2.69, 23.29, 'ICB', 'Undervalued', 'Slightly Undervalued')
# ('RELIANCE1', 12.7, 14.33, 11.6, 2.73, 12.83, 'AIMS', 'Undervalued', 'Slightly Undervalued')
# ('SEMLFBSLGF', 9.9, 12.24, 12.06, 0.18, 23.64, 'STRATEGIC', 'Undervalued', 'Slightly Undervalued')
# ('SEMLIBBLSF', 13.0, 11.19, 11.87, -0.68, -13.92, 'STRATEGIC', 'Overvalued', 'Slightly Overvalued')
# ('SEMLLECMF', 10.8, 11.62, 12.55, -0.93, 7.59, 'STRATEGIC', 'Undervalued', 'Slightly Undervalued')
# ('TRUSTB1MF', 6.7, 12.07, 11.74, 0.33, 80.15, 'RACE', 'Undervalued', 'Heavily Undervalued')
# ('VAMLBDMF1', 9.3, 12.5, 11.69, 0.81, 34.41, 'VANGUARD', 'Undervalued', 'Moderately Undervalued')
# ('VAMLRBBF', 8.8, 11.13, 11.02, 0.11, 26.48, 'VANGUARD', 'Undervalued', 'Slightly Undervalued')

# %%
# %load_ext sql

# %%
# %sql oracle+cx_oracle://litu:litu@localhost/?service_name=orcl

# %%
# %sql select * from mutual_fund
# Out:
#  * oracle+cx_oracle://litu:***@localhost/?service_name=orcl
# 0 rows affected.
# [('1JANATAMF', Decimal('6.6'), Decimal('11.85'), Decimal('11.69'), Decimal('0.16'), Decimal('79.55'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('1STPRIMFMF', Decimal('19.7'), Decimal('12.82'), Decimal('17.89'), Decimal('-5.07'), Decimal('-34.92'), 'ICB', 'Overvalued', 'Moderately Overvalued'),
#  ('ABB1STMF', Decimal('6.7'), Decimal('11.95'), Decimal('11.98'), Decimal('-0.03'), Decimal('78.36'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('AIBL1STIMF', Decimal('9.9'), Decimal('11.89'), Decimal('11.31'), Decimal('0.58'), Decimal('20.1'), 'LRGGLOBAL', 'Undervalued', 'Slightly Undervalued'),
#  ('ATCSLGF', Decimal('10.6'), Decimal('12.4'), Decimal('11.95'), Decimal('0.45'), Decimal('16.98'), 'AT-CAPITAL', 'Undervalued', 'Slightly Undervalued'),
#  ('CAPMBDBLMF', Decimal('10.3'), Decimal('11.4'), Decimal('11.74'), Decimal('-0.34'), Decimal('10.68'), 'CAPM', 'Undervalued', 'Slightly Undervalued'),
#  ('CAPMIBBLMF', Decimal('22.6'), Decimal('11.61'), Decimal('11.54'), Decimal('0.07'), Decimal('-48.63'), 'CAPM', 'Overvalued', 'Moderately Overvalued'),
#  ('DBH1STMF', Decimal('7.7'), Decimal('11.9'), Decimal('11.07'), Decimal('0.83'), Decimal('54.55'), 'LRGGLOBAL', 'Undervalued', 'Moderately Undervalued'),
#  ('EBL1STMF', Decimal('7.6'), Decimal('11.81'), Decimal('11.51'), Decimal('0.3'), Decimal('55.39'), 'RACE', 'Undervalued', 'Moderately Undervalued'),
#  ('EBLNRBMF', Decimal('6.8'), Decimal('11.96'), Decimal('11.15'), Decimal('0.81'), Decimal('75.88'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('EXIM1STMF', Decimal('6.8'), Decimal('11.79'), Decimal('11.46'), Decimal('0.33'), Decimal('73.38'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('FBFIF', Decimal('5.9'), Decimal('11.67'), Decimal('11.11'), Decimal('0.56'), Decimal('97.8'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('GRAMEENS2', Decimal('17.4'), Decimal('20.14'), Decimal('11.45'), Decimal('8.69'), Decimal('15.75'), 'AIMS', 'Undervalued', 'Slightly Undervalued'),
#  ('GREENDELMF', Decimal('8'), Decimal('11.67'), Decimal('11.09'), Decimal('0.58'), Decimal('45.88'), 'LRGGLOBAL', 'Undervalued', 'Moderately Undervalued'),
#  ('ICB3RDNRB', Decimal('6.8'), Decimal('8.59'), Decimal('11.79'), Decimal('-3.2'), Decimal('26.32'), 'ICB', 'Undervalued', 'Slightly Undervalued'),
#  ('ICBAGRANI1', Decimal('9'), Decimal('10.46'), Decimal('11.19'), Decimal('-0.73'), Decimal('16.22'), 'ICB', 'Undervalued', 'Slightly Undervalued'),
#  ('ICBAMCL2ND', Decimal('10.2'), Decimal('9.75'), Decimal('13.67'), Decimal('-3.92'), Decimal('-4.41'), 'ICB', 'Overvalued', 'Slightly Overvalued'),
#  ('ICBEPMF1S1', Decimal('7.4'), Decimal('8.64'), Decimal('11.98'), Decimal('-3.34'), Decimal('16.76'), 'ICB', 'Undervalued', 'Slightly Undervalued'),
#  ('ICBSONALI1', Decimal('8.9'), Decimal('9.75'), Decimal('11.71'), Decimal('-1.96'), Decimal('9.55'), 'ICB', 'Undervalued', 'Slightly Undervalued'),
#  ('IFIC1STMF', Decimal('6.4'), Decimal('11.59'), Decimal('11.35'), Decimal('0.24'), Decimal('81.09'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('IFILISLMF1', Decimal('6.7'), Decimal('8.75'), Decimal('11'), Decimal('-2.25'), Decimal('30.6'), 'RACE', 'Undervalued', 'Moderately Undervalued'),
#  ('LRGLOBMF1', Decimal('7.6'), Decimal('12.32'), Decimal('11.21'), Decimal('1.11'), Decimal('62.11'), 'LRGGLOBAL', 'Undervalued', 'Heavily Undervalued'),
#  ('MBL1STMF', Decimal('9.1'), Decimal('12.27'), Decimal('11.26'), Decimal('1.01'), Decimal('34.84'), 'LRGGLOBAL', 'Undervalued', 'Moderately Undervalued'),
#  ('NCCBLMF1', Decimal('8.4'), Decimal('11.78'), Decimal('10.54'), Decimal('1.24'), Decimal('40.24'), 'LRGGLOBAL', 'Undervalued', 'Moderately Undervalued'),
#  ('NLI1STMF', Decimal('15.3'), Decimal('15.23'), Decimal('13.84'), Decimal('1.39'), Decimal('-0.46'), 'VIPB', 'Overvalued', 'Slightly Overvalued'),
#  ('PF1STMF', Decimal('11.5'), Decimal('9.03'), Decimal('12.03'), Decimal('-3'), Decimal('-21.48'), 'ICB', 'Overvalued', 'Slightly Overvalued'),
#  ('PHPMF1', Decimal('6.5'), Decimal('11.76'), Decimal('11.25'), Decimal('0.51'), Decimal('80.92'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('POPULAR1MF', Decimal('6'), Decimal('11.81'), Decimal('11.62'), Decimal('0.19'), Decimal('96.83'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('PRIME1ICBA', Decimal('7.6'), Decimal('9.37'), Decimal('12.06'), Decimal('-2.69'), Decimal('23.29'), 'ICB', 'Undervalued', 'Slightly Undervalued'),
#  ('RELIANCE1', Decimal('12.7'), Decimal('14.33'), Decimal('11.6'), Decimal('2.73'), Decimal('12.83'), 'AIMS', 'Undervalued', 'Slightly Undervalued'),
#  ('SEMLFBSLGF', Decimal('9.9'), Decimal('12.24'), Decimal('12.06'), Decimal('0.18'), Decimal('23.64'), 'STRATEGIC', 'Undervalued', 'Slightly Undervalued'),
#  ('SEMLIBBLSF', Decimal('13'), Decimal('11.19'), Decimal('11.87'), Decimal('-0.68'), Decimal('-13.92'), 'STRATEGIC', 'Overvalued', 'Slightly Overvalued'),
#  ('SEMLLECMF', Decimal('10.8'), Decimal('11.62'), Decimal('12.55'), Decimal('-0.93'), Decimal('7.59'), 'STRATEGIC', 'Undervalued', 'Slightly Undervalued'),
#  ('TRUSTB1MF', Decimal('6.7'), Decimal('12.07'), Decimal('11.74'), Decimal('0.33'), Decimal('80.15'), 'RACE', 'Undervalued', 'Heavily Undervalued'),
#  ('VAMLBDMF1', Decimal('9.3'), Decimal('12.5'), Decimal('11.69'), Decimal('0.81'), Decimal('34.41'), 'VANGUARD', 'Undervalued', 'Moderately Undervalued'),
#  ('VAMLRBBF', Decimal('8.8'), Decimal('11.13'), Decimal('11.02'), Decimal('0.11'), Decimal('26.48'), 'VANGUARD', 'Undervalued', 'Slightly Undervalued')]
